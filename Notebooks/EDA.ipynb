# %%
import pandas as pd

df = pd.read_csv('/Users/shantanubhambore/Downloads/code/Customer churn analysis/Data/cleaned/telco_cleaned.csv')

# %%
df['Churn'].value_counts(normalize=True)
# Out:
# Churn
# No     0.734215
# Yes    0.265785
# Name: proportion, dtype: float64

# %%
df.groupby('Contract')['Churn'].value_counts(normalize=True)
# Out:
# Contract        Churn
# Month-to-month  No       0.572903
#                 Yes      0.427097
# One year        No       0.887228
#                 Yes      0.112772
# Two year        No       0.971513
#                 Yes      0.028487
# Name: proportion, dtype: float64

# %%
df.groupby('Churn')[['MonthlyCharges', 'tenure']].mean()
# Out:
#        MonthlyCharges     tenure
# Churn
# No          61.307408  37.650010
# Yes         74.441332  17.979133

# %%
df.groupby('InternetService')['Churn'].value_counts(normalize=True)
# Out:
# InternetService  Churn
# DSL              No       0.810017
#                  Yes      0.189983
# Fiber optic      No       0.581072
#                  Yes      0.418928
# No               No       0.925658
#                  Yes      0.074342
# Name: proportion, dtype: float64

# %%
df.groupby('SeniorCitizen')['Churn'].value_counts(normalize=True)
# Out:
# SeniorCitizen  Churn
# No             No       0.763497
#                Yes      0.236503
# Yes            No       0.583187
#                Yes      0.416813
# Name: proportion, dtype: float64
